# %% [markdown]
# ## Developing a Beer recommendation system using crowdsourced data.

# %%
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
from selenium import webdriver
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--dns-prefetch-disable")
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
from selenium.webdriver.support.wait import WebDriverWait
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from string import punctuation
import re
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import WebDriverException
from sklearn.cluster import KMeans
from sklearn import manifold
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
import seaborn as sns
import spacy 
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

## Libraries for Tokenizer and Stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/sharang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sharang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# %% [markdown]
# ### Task A
# Extract about 10k reviews of beers from Beeradvocate.com. I would suggest choosing the following link, which shows the top 250 beers sorted by ratings:
#
# We have already saved the data in a csv and attached it to our submission. For your convenience, please skip to <b>Task B</b>.

# %%
#Create a Dataframe to store all the scapred data.

reviews = pd.DataFrame(columns = ['Beer Name','User Name','User Review','Rating'])

# %%
#Get Driver of the website.

url = 'https://www.beeradvocate.com/beer/top-rated/'
driver = webdriver.Chrome()
driver.get(url)

# %%
#Scraping the 1-25 reviews of the 250 beers. 
number = 0;

#Loop to go through all the beers
for j in range(2,252):
    #Get and click on the link for every beer
    link = driver.find_elements_by_xpath('//*[@id="ba-content"]/table/tbody/tr['+str(j)+']/td[2]/a')[0]
    link.click()
    
    #Get the name of the beer
    beername = driver.find_elements_by_xpath('//*[@id="content"]/div/div/div[3]/div/div/div[1]/h1')[0]
    Beer = beername.text.split('\n')[0]
    
    #loop to go through all the reviews for the beer
    for i in range(25):
        try:
            #Get the entire HTML table row.
            fullrow = driver.find_elements_by_xpath('//*[@id="rating_fullview_content_2"]')[i]
            rowtext = fullrow.text
            
            #Split it into the ratings, review and username
            splitcomment = rowtext.split('\n') 
            rating = splitcomment[0].split(' ')[0]
            review = splitcomment[3:-3]
            userfull = splitcomment[-1].split(',')
            user = userfull[0]
            print("Beer number",j-1,": ",Beer + "\tReview Number:",i)
            
            #Saving it to a DataFrame
            reviews.loc[len(reviews)] = [Beer,user,review,rating]
        except:
            print("Skipping this comment, Error thrown")
    
    #Go back to the main page. The one with the top 250 beers list. 
    driver.execute_script("window.history.go(-1)")

# %%
reviews.head(5)

# %% [markdown]
# <br>As an <b>added</b> feature for our assignment, we have also scraped 25-50 reviews for each of our beers. This is the code.
# We will be perfoming pagination.

# %%
#Create a Dataframe to store all the scapred data.

reviews2 = pd.DataFrame(columns = ['Beer Name','User Name','User Review','Rating'])

# %%
#Get Driver of the website.

url = 'https://www.beeradvocate.com/beer/top-rated/'
driver = webdriver.Chrome()
driver.get(url)

# %%
#Scraping the 25-50 reviews of the 250 beers.
#Because this scraper have to click on 2 links and not just 1, it's not very reliable. 
#It's glitchy and can sometime cause errors. 
number = 0;

#Loop to go through all the beers
for j in range(2,4):
    try: 
        #Get and click on the link for every beer
        link = driver.find_elements_by_xpath('//*[@id="ba-content"]/table/tbody/tr['+str(j)+']/td[2]/a')[0]
        link.click()
        
        #This is the main line for this loop. We click on the 25-50 link on the Beer's webpage. 
        #This will take us to the next page of the reviews section
        #We are accomplishing pagination this way
        link2 = driver.find_elements_by_xpath('//*[@id="ba-content"]/div[11]/span/a[1]')[0]
        link2.click()
        
        #Get the name of the beer
        beername = driver.find_elements_by_xpath('//*[@id="content"]/div/div/div[3]/div/div/div[1]/h1')[0]
        Beer = beername.text.split('\n')[0]
        print(Beer)
        
        #loop to go through all the reviews for the beer
        for i in range(25):
            try:
                #Get the entire HTML table row.
                fullrow = driver.find_elements_by_xpath('//*[@id="rating_fullview_content_2"]')[i]
                rowtext = fullrow.text
                
                #Split it into the ratings, review and username
                splitcomment = rowtext.split('\n') 
                rating = splitcomment[0].split(' ')[0]
                review = splitcomment[3:-3]
                userfull = splitcomment[-1].split(',')
                user = userfull[0]
                print("Beer:",Beer + "Review Number:",i+50)
                
                #Saving it to a DataFrame
                reviews2.loc[len(reviews2)] = [Beer,user,review,rating]
            except:
                print("Skipping this comment, Error thrown")
                
        #Go back to the main page. The one with the top 250 beers list.
        #This extra line of code is also important, since now we're going back two pages and not just one. 
        driver.execute_script("window.history.go(-1)")
        driver.execute_script("window.history.go(-1)")
    except:
        print("Skipping this Beer, Error thrown")

# %%
reviews2.head(5)

# %%
#Appending 1-25 review dataframe with the 25-50 Dataframe.
finalreviews = reviews.append(reviews2).copy()

#As you can see, the ratings in our DataFrame are of the 4.55/5 format.
#Changing that to one number. 
for i in range(len(finalreviews)):
    finalreviews.iloc[i,3] = finalreviews.iloc[i,3].split('/')[0]
finalreviews

# %%
#Saving the file in a CSV.
finalreviews.to_csv("BeerReviewsMiddle33.csv",index=False)

# %% [markdown]
# ## Task B

# %%
#Loading the scraped data into a dataframe.
comments = pd.read_csv(r'BeerReviews.csv')
comments.head()
# Out:
#                      Beer Name      User Name  \
# 0  Kentucky Brunch Brand Stout      Ciocanelu
# 1  Kentucky Brunch Brand Stout      Phineasco
# 2  Kentucky Brunch Brand Stout          Slack
# 3  Kentucky Brunch Brand Stout    miniditka77
# 4  Kentucky Brunch Brand Stout  DoctorZombies
#
#                                          User Review  Rating
# 0  ['2016 Silver Wax. Aroma has whiskey, maple, t...    4.80
# 1  ['The beer pours Pitch Black with a frothy tan...    4.74
# 2  ["Probably the smoothest beer I have ever had....    4.68
# 3  ['Dark black, very thick, a little bit of tan ...    5.00
# 4  ['Poured black as ink with thin ruby edges at ...    4.97

# %%
#Loading the word replacement file which has all the replacements to be made into a dataframe
df_replacements = pd.read_excel("BeerAttributes.xls")
df_replacements.head()
# Out:
#     attribute        word
# 0  aggressive        bold
# 1  aggressive   assertive
# 2  aggressive       heavy
# 3  aggressive      strong
# 4    balanced  proportion

# %%
# Word frequency count

# Cleaning the Tweets and get the WordCount
filteredComments = comments
master_list = []
i =0
for comment in comments['User Review']:
    
    #break sentence to words
    words = word_tokenize(str(comment))
    
    #Lower case
    words = [word.lower() for word in words]
    
    #Remove single-character tokens (mostly punctuation)
    words = [word for word in words if len(word) > 1]
  
    #Remove special character sequences like ...,''''''
    words = [word for word in words if word.isalnum()]
    
    #Replace words
    for word in words:
        my_word = re.sub('[^a-zA-Z0-9 \n\.]', '', word)
        if my_word in df_replacements['word'].values:
            words[words.index(word)] = df_replacements[df_replacements['word']==word]['attribute'].values[0] 
      
    #Remove numbers
    words = [word for word in words if not word.isnumeric()]
    
    #Remove duplicates (we want to count frequency of a word as 1 even if it has been used more than once in a single comment)
    unique_words = []
    [unique_words.append(word) for word in words if word not in unique_words]   
    
    #Remove stop words
    stop_words=set(stopwords.words("english"))
    filtered_words = []
    for word in unique_words:
        if word not in stop_words:
            filtered_words.append(word)
    
    master_list.extend(filtered_words)
    filteredComments.loc[i,'Filtered_Tweet'] = ' '.join(filtered_words)
    i=i+1
wordfreq = FreqDist(master_list)
wordfreq
# Out:
# FreqDist({'head': 5595, 'malty': 4806, 'beer': 4710, 'crisp': 4702, 'taste': 3353, 'fruity': 2851, 'hoppy': 2770, 'like': 2708, 'one': 2680, 'finish': 2599, ...})

# %%
wordfreq.most_common()
# Out:
# [('head', 5595),
#  ('malty', 4806),
#  ('beer', 4710),
#  ('crisp', 4702),
#  ('taste', 3353),
#  ('fruity', 2851),
#  ('hoppy', 2770),
#  ('like', 2708),
#  ('one', 2680),
#  ('finish', 2599),
#  ('nose', 2595),
#  ('dark', 2576),
#  ('chocolate', 2554),
#  ('nice', 2467),
#  ('well', 2396),
#  ('good', 2389),
#  ('body', 2246),
#  ('lacing', 2196),
#  ('light', 2154),
#  ('robust', 2139),
#  ('notes', 2119),
#  ('flavor', 2115),
#  ('aroma', 2102),
#  ('bottle', 2085),
#  ('black', 2045),
#  ('bourbon', 1975),
#  ('white', 1971),
#  ('bit', 1968),
#  ('vanilla', 1946),
#  ('color', 1938),
#  ('glass', 1926),
#  ('mouthfeel', 1917),
#  ('little', 1911),
#  ('great', 1880),
#  ('medium', 1873),
#  ('really', 1854),
#  ('pours', 1843),
#  ('orange', 1813),
#  ('flavors', 1770),
#  ('coffee', 1748),
#  ('thick', 1724),
#  ('aggressive', 1678),
#  ('hoppy ', 1619),
#  ('barrel', 1528),
#  ('overall', 1523),
#  ('much', 1518),
#  ('bitterness', 1501),
#  ('complex', 1488),
#  ('oak', 1487),
#  ('brown', 1468),
#  ('feel', 1467),
#  ('creamy', 1441),
#  ('sweetness', 1423),
#  ('hazy', 1304),
#  ('poured', 1264),
#  ('smell', 1261),
#  ('balanced', 1259),
#  ('stout', 1250),
#  ('best', 1226),
#  ('big', 1217),
#  ('bitter', 1201),
#  ('would', 1186),
#  ('alcohol', 1184),
#  ('still', 1154),
#  ('get', 1142),
#  ('thin', 1104),
#  ('almost', 1086),
#  ('slightly', 1041),
#  ('pour', 1023),
#  ('tropical', 1023),
#  ('grapefruit', 1017),
#  ('bodied', 997),
#  ('finger', 995),
#  ('ipa', 959),
#  ('quite', 958),
#  ('abv', 943),
#  ('sour', 935),
#  ('beers', 926),
#  ('hint', 923),
#  ('slight', 911),
#  ('tart', 892),
#  ('drink', 885),
#  ('palate', 884),
#  ('also', 883),
#  ('balance', 883),
#  ('smells', 868),
#  ('retention', 865),
#  ('mango', 859),
#  ('way', 854),
#  ('even', 849),
#  ('funk', 846),
#  ('lots', 839),
#  ('pineapple', 838),
#  ('time', 825),
#  ('first', 821),
#  ('better', 819),
#  ('definitely', 819),
#  ('touch', 804),
#  ('pretty', 798),
#  ('super', 794),
#  ('soft', 793),
#  ('juicy', 792),
#  ('tan', 781),
#  ('fresh', 780),
#  ('quickly', 779),
#  ('golden', 775),
#  ('mouth', 771),
#  ('back', 769),
#  ('amazing', 764),
#  ('pine', 761),
#  ('try', 741),
#  ('moderate', 731),
#  ('deep', 728),
#  ('front', 723),
#  ('excellent', 717),
#  ('end', 711),
#  ('roasted', 711),
#  ('perfect', 709),
#  ('lemon', 708),
#  ('mild', 706),
#  ('ever', 698),
#  ('lot', 695),
#  ('around', 695),
#  ('malts', 691),
#  ('style', 691),
#  ('could', 690),
#  ('delicious', 678),
#  ('aromas', 667),
#  ('top', 663),
#  ('maple', 661),
#  ('think', 659),
#  ('juice', 647),
#  ('yellow', 646),
#  ('small', 643),
#  ('huge', 642),
#  ('sugar', 642),
#  ('follows', 622),
#  ('brew', 620),
#  ('though', 618),
#  ('amount', 618),
#  ('wine', 618),
#  ('tastes', 608),
#  ('sticky', 606),
#  ('boozy', 598),
#  ('molasses', 595),
#  ('peach', 595),
#  ('snifter', 592),
#  ('foam', 589),
#  ('vintage', 585),
#  ('two', 584),
#  ('character', 582),
#  ('easy', 581),
#  ('right', 577),
#  ('bright', 573),
#  ('booze', 558),
#  ('dank', 556),
#  ('drinkable', 555),
#  ('high', 553),
#  ('long', 552),
#  ('comes', 551),
#  ('subtle', 546),
#  ('heat', 545),
#  ('drinking', 545),
#  ('ring', 542),
#  ('worth', 538),
#  ('low', 535),
#  ('tulip', 533),
#  ('leaves', 531),
#  ('love', 528),
#  ('maybe', 527),
#  ('fantastic', 524),
#  ('solid', 521),
#  ('aged', 519),
#  ('opaque', 519),
#  ('lingering', 517),
#  ('expected', 515),
#  ('tongue', 510),
#  ('hints', 510),
#  ('cocoa', 509),
#  ('sip', 499),
#  ('side', 498),
#  ('coconut', 495),
#  ('base', 495),
#  ('toffee', 494),
#  ('oz', 494),
#  ('cinnamon', 493),
#  ('another', 486),
#  ('red', 484),
#  ('appearance', 481),
#  ('enough', 481),
#  ('along', 479),
#  ('beautiful', 478),
#  ('yet', 476),
#  ('stouts', 470),
#  ('got', 468),
#  ('brewery', 467),
#  ('fairly', 466),
#  ('roast', 465),
#  ('hype', 458),
#  ('warms', 458),
#  ('sure', 458),
#  ('floral', 458),
#  ('milk', 457),
#  ('lace', 455),
#  ('without', 455),
#  ('profile', 455),
#  ('cherry', 455),
#  ('aftertaste', 453),
#  ('minimal', 452),
#  ('come', 441),
#  ('finishes', 441),
#  ('syrup', 437),
#  ('tap', 434),
#  ('say', 434),
#  ('less', 433),
#  ('favorite', 433),
#  ('presence', 429),
#  ('tartness', 428),
#  ('clear', 427),
#  ('funky', 422),
#  ('looks', 421),
#  ('clean', 421),
#  ('honey', 418),
#  ('going', 416),
#  ('nicely', 412),
#  ('forward', 411),
#  ('makes', 411),
#  ('present', 407),
#  ('mocha', 404),
#  ('green', 400),
#  ('incredible', 399),
#  ('cloudy', 390),
#  ('half', 389),
#  ('similar', 387),
#  ('tangerine', 386),
#  ('wood', 385),
#  ('years', 384),
#  ('tons', 384),
#  ('fluffy', 384),
#  ('probably', 380),
#  ('awesome', 380),
#  ('enjoyable', 380),
#  ('old', 379),
#  ('tasty', 377),
#  ('note', 376),
#  ('absolutely', 376),
#  ('thanks', 373),
#  ('followed', 372),
#  ('wonderful', 369),
#  ('never', 366),
#  ('level', 365),
#  ('foamy', 365),
#  ('everything', 364),
#  ('thing', 363),
#  ('ba', 362),
#  ('make', 362),
#  ('bubbles', 361),
#  ('date', 356),
#  ('look', 351),
#  ('world', 350),
#  ('something', 350),
#  ('done', 350),
#  ('apricot', 350),
#  ('roasty', 349),
#  ('leaving', 347),
#  ('gold', 347),
#  ('away', 346),
#  ('looking', 345),
#  ('fudge', 345),
#  ('pleasant', 344),
#  ('pale', 344),
#  ('overly', 341),
#  ('imperial', 340),
#  ('perfectly', 339),
#  ('decent', 339),
#  ('drank', 338),
#  ('dipa', 337),
#  ('faint', 335),
#  ('yeast', 335),
#  ('bite', 334),
#  ('acidity', 332),
#  ('want', 331),
#  ('see', 330),
#  ('pitch', 328),
#  ('day', 327),
#  ('enjoyed', 326),
#  ('extremely', 326),
#  ('colored', 323),
#  ('lightly', 322),
#  ('lingers', 322),
#  ('intense', 322),
#  ('tasting', 322),
#  ('seems', 321),
#  ('house', 321),
#  ('cap', 320),
#  ('together', 319),
#  ('quality', 318),
#  ('find', 317),
#  ('fine', 317),
#  ('carb', 316),
#  ('slowly', 313),
#  ('every', 312),
#  ('oily', 311),
#  ('dense', 308),
#  ('version', 307),
#  ('apple', 307),
#  ('new', 305),
#  ('acidic', 305),
#  ('pepper', 304),
#  ('nothing', 304),
#  ('glad', 304),
#  ('fades', 303),
#  ('far', 302),
#  ('frothy', 301),
#  ('coming', 301),
#  ('incredibly', 301),
#  ('chewy', 300),
#  ('warming', 299),
#  ('wow', 297),
#  ('tree', 297),
#  ('refreshing', 295),
#  ('throughout', 293),
#  ('outstanding', 291),
#  ('point', 291),
#  ('bomb', 291),
#  ('ale', 290),
#  ('experience', 289),
#  ('blend', 289),
#  ('year', 287),
#  ('hard', 287),
#  ('plenty', 287),
#  ('behind', 286),
#  ('certainly', 286),
#  ('cream', 285),
#  ('raspberry', 285),
#  ('viscous', 283),
#  ('inch', 282),
#  ('know', 282),
#  ('silky', 281),
#  ('toasted', 281),
#  ('different', 281),
#  ('double', 281),
#  ('amber', 280),
#  ('piney', 279),
#  ('cherries', 278),
#  ('hot', 278),
#  ('go', 277),
#  ('sourness', 277),
#  ('real', 276),
#  ('actually', 276),
#  ('ipas', 275),
#  ('getting', 273),
#  ('somewhat', 273),
#  ('tried', 272),
#  ('made', 271),
#  ('ca', 269),
#  ('trillium', 269),
#  ('melon', 266),
#  ('stuff', 263),
#  ('haze', 263),
#  ('class', 262),
#  ('goes', 262),
#  ('burn', 261),
#  ('might', 261),
#  ('last', 261),
#  ('burnt', 259),
#  ('mix', 258),
#  ('may', 258),
#  ('enjoy', 257),
#  ('take', 257),
#  ('murky', 256),
#  ('left', 255),
#  ('dissipates', 255),
#  ('straw', 253),
#  ('zest', 253),
#  ('middle', 252),
#  ('mostly', 251),
#  ('fingers', 250),
#  ('regular', 249),
#  ('hidden', 249),
#  ('texture', 248),
#  ('nearly', 248),
#  ('licorice', 248),
#  ('wish', 247),
#  ('kind', 245),
#  ('raisins', 243),
#  ('surprisingly', 242),
#  ('however', 241),
#  ('batch', 241),
#  ('khaki', 241),
#  ('starts', 241),
#  ('papaya', 241),
#  ('finally', 240),
#  ('gets', 240),
#  ('rind', 240),
#  ('oil', 239),
#  ('lighter', 239),
#  ('stone', 239),
#  ('brings', 238),
#  ('syrupy', 236),
#  ('rather', 236),
#  ('sharp', 235),
#  ('pint', 235),
#  ('peel', 234),
#  ('tasted', 233),
#  ('release', 233),
#  ('raisin', 232),
#  ('grass', 232),
#  ('warm', 231),
#  ('damn', 231),
#  ('ripe', 230),
#  ('highly', 229),
#  ('background', 229),
#  ('char', 228),
#  ('age', 225),
#  ('grape', 225),
#  ('review', 224),
#  ('interesting', 224),
#  ('settles', 223),
#  ('tobacco', 222),
#  ('bad', 221),
#  ('resin', 220),
#  ('perhaps', 219),
#  ('hill', 219),
#  ('near', 217),
#  ('barrels', 216),
#  ('liquid', 216),
#  ('whiskey', 215),
#  ('adds', 214),
#  ('classic', 214),
#  ('slick', 212),
#  ('especially', 212),
#  ('noticeable', 212),
#  ('ago', 212),
#  ('thought', 211),
#  ('let', 210),
#  ('grassy', 209),
#  ('hay', 209),
#  ('unique', 208),
#  ('oaky', 206),
#  ('espresso', 206),
#  ('depth', 206),
#  ('hit', 206),
#  ('dried', 206),
#  ('ton', 206),
#  ('leather', 206),
#  ('must', 205),
#  ('easily', 204),
#  ('days', 204),
#  ('price', 204),
#  ('feels', 204),
#  ('velvety', 203),
#  ('expect', 203),
#  ('decadent', 203),
#  ('offering', 203),
#  ('completely', 202),
#  ('reminds', 202),
#  ('anything', 202),
#  ('things', 201),
#  ('backbone', 200),
#  ('bread', 200),
#  ('charred', 199),
#  ('warmth', 199),
#  ('citrusy', 199),
#  ('hue', 199),
#  ('treat', 198),
#  ('ml', 198),
#  ('truly', 197),
#  ('smoke', 197),
#  ('give', 195),
#  ('flavorful', 195),
#  ('edges', 194),
#  ('always', 194),
#  ('candy', 194),
#  ('aging', 193),
#  ('else', 192),
#  ('impressive', 192),
#  ('although', 192),
#  ('wild', 192),
#  ('wet', 191),
#  ('served', 191),
#  ('loads', 190),
#  ('said', 190),
#  ('hits', 190),
#  ('least', 189),
#  ('next', 189),
#  ('across', 189),
#  ('barnyard', 189),
#  ('woody', 188),
#  ('prefer', 188),
#  ('moderately', 187),
#  ('trying', 186),
#  ('farmstead', 186),
#  ('ruby', 185),
#  ('since', 185),
#  ('large', 185),
#  ('drinks', 185),
#  ('edge', 184),
#  ('cloying', 183),
#  ('teku', 183),
#  ('close', 183),
#  ('mellow', 183),
#  ('candied', 182),
#  ('prominent', 181),
#  ('given', 179),
#  ('start', 178),
#  ('found', 178),
#  ('straight', 178),
#  ('layer', 178),
#  ('dated', 178),
#  ('pink', 178),
#  ('dryness', 177),
#  ('jet', 176),
#  ('bottled', 176),
#  ('wheat', 176),
#  ('saison', 176),
#  ('canned', 175),
#  ('typical', 175),
#  ('draft', 174),
#  ('whole', 173),
#  ('upfront', 173),
#  ('citra', 173),
#  ('fan', 172),
#  ('linger', 171),
#  ('mixed', 171),
#  ('hf', 171),
#  ('three', 170),
#  ('booziness', 170),
#  ('trade', 170),
#  ('lovely', 170),
#  ('bready', 170),
#  ('plus', 169),
#  ('guava', 169),
#  ('coating', 168),
#  ('second', 168),
#  ('resinous', 168),
#  ('couple', 167),
#  ('short', 167),
#  ('average', 167),
#  ('delicate', 167),
#  ('bottles', 166),
#  ('put', 166),
#  ('collar', 166),
#  ('others', 165),
#  ('share', 165),
#  ('lambic', 165),
#  ('seem', 164),
#  ('peppery', 164),
#  ('immediately', 163),
#  ('part', 163),
#  ('night', 162),
#  ('able', 162),
#  ('tiny', 162),
#  ('motor', 161),
#  ('dankness', 161),
#  ('overwhelming', 160),
#  ('ne', 160),
#  ('overpowering', 159),
#  ('initial', 159),
#  ('sweeter', 159),
#  ('vinegar', 158),
#  ('nutty', 157),
#  ('room', 157),
#  ('expecting', 156),
#  ('special', 156),
#  ('came', 155),
#  ('grain', 155),
#  ('cold', 155),
#  ('spotty', 154),
#  ('massive', 153),
#  ('recedes', 153),
#  ('despite', 153),
#  ('line', 153),
#  ('peppers', 152),
#  ('type', 151),
#  ('wait', 150),
#  ('punch', 150),
#  ('dessert', 150),
#  ('rating', 149),
#  ('keep', 149),
#  ('peaches', 149),
#  ('cake', 148),
#  ('musty', 148),
#  ('making', 148),
#  ('legs', 147),
#  ('shared', 147),
#  ('coats', 147),
#  ('fair', 147),
#  ('sipper', 147),
#  ('grapes', 147),
#  ('neipa', 146),
#  ('months', 145),
#  ('takes', 145),
#  ('brett', 145),
#  ('swallow', 144),
#  ('bar', 144),
#  ('pith', 144),
#  ('west', 144),
#  ('cellar', 144),
#  ('chance', 143),
#  ('due', 143),
#  ('compared', 143),
#  ('raspberries', 143),
#  ('towards', 142),
#  ('lactic', 142),
#  ('add', 140),
#  ('pure', 140),
#  ('people', 140),
#  ('gives', 140),
#  ('need', 139),
#  ('upon', 138),
#  ('plum', 138),
#  ('oh', 138),
#  ('coast', 138),
#  ('growler', 138),
#  ('times', 137),
#  ('julius', 137),
#  ('either', 136),
#  ('marshmallow', 136),
#  ('pungent', 136),
#  ('cantillon', 136),
#  ('phenomenal', 135),
#  ('th', 135),
#  ('pick', 135),
#  ('leave', 134),
#  ('lime', 134),
#  ('lasting', 133),
#  ('surface', 133),
#  ('passion', 133),
#  ('buy', 133),
#  ('oranges', 133),
#  ('mildly', 132),
#  ('mosaic', 132),
#  ('round', 130),
#  ('standard', 130),
#  ('mind', 129),
#  ('beige', 129),
#  ('film', 129),
#  ('course', 129),
#  ('fruitiness', 129),
#  ('tad', 128),
#  ('earth', 128),
#  ('happy', 128),
#  ('believe', 128),
#  ('drinkability', 128),
#  ('goodness', 127),
#  ('simply', 127),
#  ('american', 127),
#  ('brandy', 127),
#  ('work', 127),
#  ('king', 127),
#  ('sours', 127),
#  ('thinner', 126),
#  ('tones', 126),
#  ('belgian', 126),
#  ('figs', 124),
#  ('integrated', 124),
#  ('exceptional', 124),
#  ('pop', 124),
#  ('chili', 124),
#  ('dominate', 124),
#  ('brownie', 123),
#  ('soapy', 123),
#  ('example', 123),
#  ('750ml', 123),
#  ('porter', 123),
#  ('sugary', 122),
#  ('honestly', 122),
#  ('spices', 122),
#  ('vinous', 122),
#  ('crazy', 121),
#  ('guess', 121),
#  ('rum', 121),
#  ('earthiness', 120),
#  ('warmed', 119),
#  ('sort', 119),
#  ('added', 119),
#  ('lively', 119),
#  ('beautifully', 119),
#  ('layers', 118),
#  ('sticks', 118),
#  ('works', 118),
#  ('flat', 118),
#  ('bottom', 117),
#  ('true', 117),
#  ('loved', 117),
#  ('offerings', 117),
#  ('opened', 116),
#  ('finishing', 116),
#  ('show', 116),
#  ('thicker', 115),
#  ('higher', 115),
#  ('friend', 115),
#  ('scent', 114),
#  ('berries', 114),
#  ('kick', 114),
#  ('expectations', 113),
#  ('cut', 113),
#  ('prickly', 113),
#  ('hues', 113),
#  ('purchased', 113),
#  ('galaxy', 113),
#  ('hands', 112),
#  ('used', 112),
#  ('gentle', 112),
#  ('week', 111),
#  ('barely', 111),
#  ('gueuze', 111),
#  ('becomes', 110),
#  ('opinion', 110),
#  ('smelling', 110),
#  ('residual', 110),
#  ('darker', 110),
#  ('exactly', 110),
#  ('fig', 110),
#  ('wanted', 109),
#  ('place', 109),
#  ('open', 109),
#  ('felt', 109),
#  ('lower', 109),
#  ('impressed', 109),
#  ('held', 109),
#  ('lactose', 109),
#  ('reduces', 108),
#  ('pronounced', 108),
#  ('muted', 107),
#  ('surprised', 107),
#  ('rye', 107),
#  ('fruited', 107),
#  ('barleywine', 107),
#  ('cola', 106),
#  ('rest', 106),
#  ('cans', 106),
#  ('label', 106),
#  ('man', 105),
#  ('subdued', 105),
#  ('lives', 105),
#  ('list', 105),
#  ('sharing', 105),
#  ('case', 105),
#  ('home', 105),
#  ('bomber', 105),
#  ('aspect', 105),
#  ('feeling', 104),
#  ('spot', 104),
#  ('disappointed', 103),
#  ('qualities', 103),
#  ('blended', 103),
#  ('opens', 103),
#  ('otherwise', 103),
#  ('dates', 103),
#  ('available', 103),
#  ('remains', 103),
#  ('face', 103),
#  ('apricots', 103),
#  ('cracker', 103),
#  ('picked', 103),
#  ('later', 102),
#  ('original', 102),
#  ('bring', 102),
#  ('blueberry', 102),
#  ('elements', 102),
#  ('acid', 102),
#  ('project', 102),
#  ('recommend', 101),
#  ('pillowy', 101),
#  ('purple', 101),
#  ('consumed', 100),
#  ('several', 100),
#  ('beans', 100),
#  ('single', 100),
#  ('combination', 100),
#  ('already', 100),
#  ('passionfruit', 100),
#  ('yeasty', 100),
#  ('weeks', 100),
#  ('imagine', 99),
#  ('impression', 99),
#  ('harsh', 99),
#  ('among', 99),
#  ('live', 99),
#  ('dangerously', 99),
#  ('minutes', 99),
#  ('wonderfully', 99),
#  ('nuts', 99),
#  ('blanket', 98),
#  ('amazingly', 98),
#  ('liked', 98),
#  ('characteristics', 98),
#  ('grains', 98),
#  ('follow', 97),
#  ('considering', 97),
#  ('soon', 97),
#  ('use', 97),
#  ('berry', 97),
#  ('zero', 96),
#  ('totally', 96),
#  ('sipping', 96),
#  ('skin', 96),
#  ('modest', 96),
#  ('jam', 96),
#  ('friends', 95),
#  ('breakfast', 95),
#  ('stands', 95),
#  ('sense', 95),
#  ('somehow', 95),
#  ('covered', 95),
#  ('strawberry', 95),
#  ('12oz', 95),
#  ('england', 95),
#  ('quick', 95),
#  ('flavour', 95),
#  ('stand', 94),
#  ('apples', 94),
#  ('shows', 94),
#  ('crafted', 94),
#  ('aromatic', 94),
#  ('late', 93),
#  ('brews', 93),
#  ('stronger', 93),
#  ('tangy', 93),
#  ('bittersweet', 93),
#  ('luscious', 92),
#  ('hope', 92),
#  ('topped', 92),
#  ('inviting', 92),
#  ('drying', 92),
#  ('addition', 92),
#  ('seek', 92),
#  ('gorgeous', 91),
#  ('brewing', 91),
#  ('fridge', 91),
#  ('tannins', 91),
#  ('powder', 91),
#  ('lemony', 91),
#  ('superb', 90),
#  ('thickness', 90),
#  ('bean', 90),
#  ('adding', 90),
#  ('reviewed', 90),
#  ('took', 90),
#  ('visible', 90),
#  ('seeking', 90),
#  ('keeps', 90),
#  ('powerful', 90),
#  ('cheese', 90),
#  ('dominant', 89),
#  ('sitting', 89),
#  ('cheers', 89),
#  ('highlights', 89),
#  ('remember', 88),
#  ('adjuncts', 88),
#  ('undertones', 88),
#  ('initially', 88),
#  ('past', 88),
#  ('treehouse', 88),
#  ('toasty', 88),
#  ('fast', 87),
#  ('tight', 87),
#  ('mahogany', 87),
#  ('effervescence', 87),
#  ('puckering', 87),
#  ('rounded', 86),
#  ('become', 86),
#  ('seemed', 86),
#  ('relatively', 86),
#  ('milky', 86),
#  ('brewed', 86),
#  ('pithy', 86),
#  ('creaminess', 86),
#  ('often', 85),
#  ('toward', 85),
#  ('form', 85),
#  ('pear', 85),
#  ('within', 85),
#  ('instead', 85),
#  ('burst', 85),
#  ('distinct', 85),
#  ('reason', 84),
#  ('spiciness', 84),
#  ('sides', 84),
#  ('reddish', 84),
#  ('potent', 83),
#  ('batter', 83),
#  ('colour', 83),
#  ('hides', 83),
#  ('tell', 83),
#  ('seen', 83),
#  ('stemmed', 83),
#  ('smelled', 82),
#  ('life', 82),
#  ('roastiness', 82),
#  ('went', 82),
#  ('temperature', 82),
#  ('intensity', 82),
#  ('apparent', 82),
#  ('biscuit', 82),
#  ('16oz', 82),
#  ('worthy', 82),
#  ('raw', 82),
#  ('none', 82),
#  ('hopped', 82),
#  ('heady', 81),
#  ('astringent', 81),
#  ('particularly', 81),
#  ('butter', 81),
#  ('banana', 81),
#  ('funkiness', 81),
#  ('substantial', 80),
#  ('opportunity', 80),
#  ('faded', 80),
#  ('fudgy', 80),
#  ('bought', 80),
#  ('weight', 80),
#  ('tall', 80),
#  ('forms', 80),
#  ('de', 80),
#  ('reviews', 79),
#  ('notch', 79),
#  ('sips', 79),
#  ('giving', 79),
#  ('leads', 79),
#  ('usual', 79),
#  ('whiff', 79),
#  ('excited', 79),
#  ('turbid', 79),
#  ('dissipated', 79),
#  ('guys', 79),
#  ('smoky', 78),
#  ('opening', 78),
#  ('lucky', 78),
#  ('yes', 78),
#  ('shine', 78),
#  ('shines', 78),
#  ('temp', 78),
#  ('disappoint', 78),
#  ('plums', 77),
#  ('ice', 77),
#  ('dominates', 77),
#  ('name', 77),
#  ('entire', 77),
#  ('center', 77),
#  ('nectarine', 77),
#  ('today', 77),
#  ('pleasure', 77),
#  ('reminiscent', 77),
#  ('barley', 77),
#  ('surprising', 76),
#  ('shot', 76),
#  ('heard', 76),
#  ('perfection', 76),
#  ('taking', 76),
#  ('definite', 76),
#  ('amounts', 76),
#  ('strength', 76),
#  ('underlying', 76),
#  ('summer', 76),
#  ('basically', 75),
#  ('usually', 75),
#  ('dominated', 75),
#  ('lack', 75),
#  ('ends', 75),
#  ('lush', 75),
#  ('executed', 75),
#  ('terms', 75),
#  ('ample', 75),
#  ('pouring', 74),
#  ('obviously', 74),
#  ('filled', 74),
#  ('rated', 74),
#  ('pleasantly', 74),
#  ('soaked', 74),
#  ('taster', 74),
#  ('insane', 74),
#  ('recently', 74),
#  ('kiwi', 74),
#  ('water', 74),
#  ('alpine', 74),
#  ('copper', 74),
#  ('possibly', 73),
#  ('balances', 73),
#  ('turns', 73),
#  ('fact', 73),
#  ('bringing', 73),
#  ('based', 73),
#  ('sediment', 73),
#  ('fuzzy', 73),
#  ('doubt', 73),
#  ('mean', 73),
#  ('atop', 73),
#  ('slow', 72),
#  ('rare', 72),
#  ('lasts', 72),
#  ('throat', 72),
#  ('hell', 72),
#  ('describe', 72),
#  ('stays', 72),
#  ('appreciate', 72),
#  ('prevalent', 72),
#  ('bursting', 72),
#  ...]

# %%
nlp = spacy.load('en_core_web_sm')
print("Enter three beer attributes as space-separated words") 
words = input()
doc2 = nlp(words)
# Out:
# Enter three beer attributes as space-separated words
# malty crisp aggressive

# %% [markdown]
# ### Task C
# Performing a similarity analysis with the 3-attribute set and the reviews. Extracting 300 reviews that have the highest similarity scores with the attribute set.

# %%
#Calculating similarity analysis with the 3 chosen attribute set and the reviews. 
similarity = list()
spacy_similarity = pd.DataFrame(columns = ['User Review','BeerName','Rating'])
for comment in comments['User Review']: 
    doc1 = nlp(comment)
    similarity.append(doc1.similarity(doc2)) 
spacy_similarity[['User Review','BeerName','Rating']] = comments[['User Review','Beer Name','Rating']]
spacy_similarity['spacy_similarity'] = similarity
spacy_similarity['attributes'] = words

# %%
#Filtering the top 300 reveiws with highest similarity scores
spacy_similarity = spacy_similarity.sort_values(by=['spacy_similarity'],ascending=False)[:300]

# %%
spacy_similarity
# Out:
#                                              User Review  \
# 5259   ['Bright copper orange in color with perfect c...
# 8363   ['2016 bottle. Craziest part was experiencing ...
# 3455   ['Very cloudy straw appearance with slight whi...
# 8353   ['Missed out first release....tried hunting an...
# 8244   ['Pours a golden hue color with a i finger egg...
# 3320   ['Pitch black and nearly opaque with dark choc...
# 9034   ['Fresh growler from Alpine. Poured a beautifu...
# 1753   ['11/17/18 (Chicago): 2 oz 15.0% ABV pour at 2...
# 1468   ['Pours a yellow and hazy color with small yel...
# 4351   ['Pour a nice smooth dark color smells of huge...
# 4902   ['5/2/19 (Chicago): $12.47 12 oz. can prepaid ...
# 9466   ['5/2/19 (Chicago): $12.47 12 oz. can prepaid ...
# 2930   ['Murky creamsicle orange in color. Poured wit...
# 4497   ["12/31/18 (Chicago): $17.99 Four Pack (plus $...
# 2552   ['Tap at The Farmhouse Burlington.', 'Slightly...
# 2361   ['Pours deep dark brown with fluffy white head...
# 3361   ['07 bottle. Pour is dark brown, almost black ...
# 7611   ['thick looking pour with lasting mocha colour...
# 6539   ['L: cloudy dark brown with full head of small...
# 9024   ['pour is clear golden orange with tons of cre...
# 3285   ['5 ounce pour at 3 Floyds in Munster. Nice da...
# 10100  ['12/29/18 (Chicago): $6.63 16 oz draft pour i...
# 1541   ['Can: Poured a bright hazy yellow color ale w...
# 3547   ['Pours a murky yellow to orange with a billow...
# 4190   ['Bottle: Poured a dark burgundy color ale wit...
# 8863   ['Pours a dark chestnut brown color that appea...
# 5112   ['16 oz can. Pours cloudy yellow orange with t...
# 9076   ['Very hazy dark orange pour with a dense whit...
# 7874   ['Great dark brown coffee color with a descent...
# 9616   ["was upset when they did away with the demon ...
# ...                                                  ...
# 4701   ['12oz can labeled 2019 poured into a Spiegela...
# 8520   ['Poured from can cloudy yellow. Amazing fruit...
# 5106   ['Pours a bright hazy straw yellow with a soap...
# 9201   ['L: Acerbic fuchsia tones with a generous whi...
# 1788   ["16oz can purchased at the brewery dated 11/1...
# 305    ["L. I poured this from the bottle into a pint...
# 7144   ['Officially one of the top beers I’ve had. Po...
# 5245   ['Copper colored with a very clear complexion....
# 3555   ['poured from a 500mL bottle into a willi bech...
# 3851   ['poured from a 12oz can into a snifter. pours...
# 2368   ['2018 version purchased at the brewery. Ruby ...
# 805    ['2012 bottled 2014, pour to snifter, purple, ...
# 4742   ['A pale, murky, juicy looking beer with a nic...
# 4157   ['A- Motor oil black pour from the 500ml bottl...
# 4062   ["Prairie Apple Brandy Barrel Noir, 12% ABV. P...
# 8572   ['Pineapple, orange/tangerine, grapefruit arom...
# 8995   ['Sampled this at darkness day. Pours a silky ...
# 4204   ['Stark black with a fuzzy mocha head settling...
# 9233   ['22oz bottle undated purchased at Moonshine. ...
# 4714   ['2018 can. Thanks Russ.', 'This was poured in...
# 9428   ['2018 can. Thanks Russ.', 'This was poured in...
# 6824   ['Pours a yellow hay color from the bottle. Sm...
# 1575   ["Got a bottle of this in July of 2017 when my...
# 9821   ['An incredible beer, arguably the standout of...
# 2713   ['Bottled on 7/19/2019.Pours into a goblet jet...
# 1396   ['Sip of Sunshine pours a semi-opaque golden, ...
# 2646   ['Trillium is an impressive brewer and this be...
# 1661   ['Poured into a snifter. Nearly opaque dark br...
# 661    ['16oz can, dated 08.01.19, poured into a Tree...
# 2120   ['Nice sour qualities but on par with a lot of...
#
#                                         BeerName  Rating  spacy_similarity  \
# 5259                       Hop JuJu Imperial IPA    4.37          0.666506
# 8363                                   The Abyss    4.47          0.653602
# 3455                3rd Anniversary Imperial IPA    4.73          0.644649
# 8353                         Hold On To Sunshine    4.79          0.642710
# 8244                           Permanent Funeral    4.25          0.638598
# 3320               Barrel-Aged Sump Coffee Stout    4.39          0.631427
# 9034                                     Bad Boy    4.72          0.631308
# 1753                                Chemtrailmix    4.38          0.631216
# 1468                          Nectarine Premiere    4.83          0.626157
# 4351                   Maple Bacon Coffee Porter    4.82          0.621444
# 4902                         Clare's Thirsty Ale    4.59          0.619732
# 9466                         Clare's Thirsty Ale    4.59          0.619732
# 2930                                  Pseudo Sue    4.40          0.619141
# 4497                                       Sosus    4.32          0.617068
# 2552                       Society & Solitude #5    4.11          0.614261
# 2361                                      §ucaba    4.64          0.608818
# 3361                     Kaggen! Stormaktsporter    4.17          0.607337
# 7611                    Last Buffalo In The Park    3.90          0.606304
# 6539              Trappist Westvleteren 12 (XII)    4.16          0.606299
# 9024                                     Bad Boy    4.10          0.605939
# 3285                           Permanent Funeral    4.34          0.605186
# 10100              Weihenstephaner Hefeweissbier    4.11          0.605103
# 1541                       Society & Solitude #4    4.50          0.605006
# 3547          Melcher Street (Double Dry-Hopped)    4.49          0.604458
# 4190                              Stickee Monkee    3.75          0.604448
# 8863   Genealogy Of Morals - Bourbon Barrel-Aged    3.92          0.604426
# 5112      Double Dry Hopped All Citra Everything    4.71          0.604393
# 9076                                     Crusher    4.46          0.603698
# 7874                                 Double Shot    4.56          0.600890
# 9616                                       Tweak    4.66          0.599666
# ...                                          ...     ...               ...
# 4701                                        BDCS    4.59          0.550351
# 8520                         Congress Street IPA    4.55          0.550288
# 5106      Double Dry Hopped All Citra Everything    4.51          0.550238
# 9201                                        DFPF    4.74          0.550027
# 1788       Double Dry Hopped Fort Point Pale Ale    4.62          0.549917
# 305               CBS (Canadian Breakfast Stout)    4.46          0.549782
# 7144                                       Green    4.84          0.549736
# 5245                       Hop JuJu Imperial IPA    4.29          0.549652
# 3555                              Everett Porter    4.49          0.549598
# 3851                       Society & Solitude #6    4.58          0.549563
# 2368                                      §ucaba    4.84          0.549540
# 805                             Lou Pepe - Kriek    4.66          0.549530
# 4742                               Citraquench'l    4.59          0.549426
# 4157                                Impermanence    4.43          0.549421
# 4062                    Apple Brandy Barrel Noir    4.27          0.549379
# 8572                Double Dry Hopped Mylar Bags    4.69          0.549319
# 8995                 Damon (Bourbon Barrel Aged)    4.43          0.549129
# 4204                 Damon (Bourbon Barrel Aged)    4.09          0.549063
# 9233                                       Sosus    4.48          0.549017
# 4714                                        BDCS    4.88          0.548982
# 9428                                        BDCS    4.88          0.548982
# 6824                                       Fuzzy    4.71          0.548826
# 1575                               Beatification    4.30          0.548690
# 9821                                   Sang Noir    4.59          0.548685
# 2713                                Pirate Bomb!    4.49          0.548616
# 1396                             Sip Of Sunshine    4.56          0.548561
# 2646                      Cutting Tiles (Mosaic)    4.64          0.548459
# 1661                                       Maman    4.34          0.548451
# 661                                   JJJuliusss    4.07          0.548436
# 2120                          Abricot Du Fermier    4.21          0.548368
#
#                    attributes
# 5259   malty crisp aggressive
# 8363   malty crisp aggressive
# 3455   malty crisp aggressive
# 8353   malty crisp aggressive
# 8244   malty crisp aggressive
# 3320   malty crisp aggressive
# 9034   malty crisp aggressive
# 1753   malty crisp aggressive
# 1468   malty crisp aggressive
# 4351   malty crisp aggressive
# 4902   malty crisp aggressive
# 9466   malty crisp aggressive
# 2930   malty crisp aggressive
# 4497   malty crisp aggressive
# 2552   malty crisp aggressive
# 2361   malty crisp aggressive
# 3361   malty crisp aggressive
# 7611   malty crisp aggressive
# 6539   malty crisp aggressive
# 9024   malty crisp aggressive
# 3285   malty crisp aggressive
# 10100  malty crisp aggressive
# 1541   malty crisp aggressive
# 3547   malty crisp aggressive
# 4190   malty crisp aggressive
# 8863   malty crisp aggressive
# 5112   malty crisp aggressive
# 9076   malty crisp aggressive
# 7874   malty crisp aggressive
# 9616   malty crisp aggressive
# ...                       ...
# 4701   malty crisp aggressive
# 8520   malty crisp aggressive
# 5106   malty crisp aggressive
# 9201   malty crisp aggressive
# 1788   malty crisp aggressive
# 305    malty crisp aggressive
# 7144   malty crisp aggressive
# 5245   malty crisp aggressive
# 3555   malty crisp aggressive
# 3851   malty crisp aggressive
# 2368   malty crisp aggressive
# 805    malty crisp aggressive
# 4742   malty crisp aggressive
# 4157   malty crisp aggressive
# 4062   malty crisp aggressive
# 8572   malty crisp aggressive
# 8995   malty crisp aggressive
# 4204   malty crisp aggressive
# 9233   malty crisp aggressive
# 4714   malty crisp aggressive
# 9428   malty crisp aggressive
# 6824   malty crisp aggressive
# 1575   malty crisp aggressive
# 9821   malty crisp aggressive
# 2713   malty crisp aggressive
# 1396   malty crisp aggressive
# 2646   malty crisp aggressive
# 1661   malty crisp aggressive
# 661    malty crisp aggressive
# 2120   malty crisp aggressive
#
# [300 rows x 5 columns]

# %% [markdown]
# ### Task D
# Performing sentiment analysis on the top 300 reviews.

# %%
# Performing Sentiment Analysis on the top 300 reviews
sid_obj = SentimentIntensityAnalyzer() 
top300 = spacy_similarity.assign(overall_sentiment="",sentiment_score="")

for index,rows in top300.iterrows():
    review = rows['User Review']
    sentiment_dict = sid_obj.polarity_scores(str(review))
    score = sentiment_dict['compound']
    if score >= 0.05 : 
        sentiment = "Positive"
    elif score <= - 0.05 : 
        sentiment = "Negative"
    else:
        sentiment = "Neutral"
        
    top300.loc[index,'sentiment_score'] = score
    top300.loc[index,'overall_sentiment'] = sentiment

# %%
# Sorting the reviews (high to low) by the sentiment 
top300.sort_values(by=['sentiment_score'],ascending=False)
# Out:
#                                              User Review  \
# 7144   ['Officially one of the top beers I’ve had. Po...
# 7386   ['750mL 2002 Yellow Label thanks to OldStyleCu...
# 1936   ['A- 500ml bottle pours a motor oil black brew...
# 3320   ['Pitch black and nearly opaque with dark choc...
# 12     ["Pouring with a thick viscosity that's damn n...
# 9070   ['Healthy two plus finger head of eggshell whi...
# 5558   ['Smell: this super barrel forward huge oak an...
# 661    ['16oz can, dated 08.01.19, poured into a Tree...
# 4902   ['5/2/19 (Chicago): $12.47 12 oz. can prepaid ...
# 9466   ['5/2/19 (Chicago): $12.47 12 oz. can prepaid ...
# 9201   ['L: Acerbic fuchsia tones with a generous whi...
# 7958   ['Another amazing imperial stout from this inc...
# 1753   ['11/17/18 (Chicago): 2 oz 15.0% ABV pour at 2...
# 9278   ['Poured into a tulip, the appearance was a ha...
# 9200   ['Spectacular beer.. A colorful fruit bomb of ...
# 3502   ['Poured gently at 46°F from a 500ml bottle (b...
# 4079   ['absolutely beautiful beer ... dark pour with...
# 8597   ['On tap at the Mule Bar, Winooski VT. This wa...
# 7650   ['Tap pour into Tulip glass. Nice hazy honey l...
# 3778   ['750ml bottle - 2016 vintage', '', 'Pours dar...
# 8603   ['Using the spicy, earthy and robust delight o...
# 10074  ['Bottle: Poured a pitch-black color stout wit...
# 4824   ["A deep, dark, rich barrel-aged imperial stou...
# 2274   ['Shared a bomber at hotel before Anniversary ...
# 8327   ["At Jason's CO Stout tasting, This was a real...
# 3533   ["Simply slathered with Mosaic hop character, ...
# 3423   ['A very nice imperial stout but the stronger ...
# 10013  ["Poured a black Stout like color with a panca...
# 5735   ["2017 bottle, poured into a Fremont small sni...
# 2442   ['L: Rich and thick mahogany mocha hues with a...
# ...                                                  ...
# 3101   ['Bottle: Poured a hazy red color Lambic with ...
# 1790   ['12 oz can canned 9/9/19 poured into a tulip ...
# 2001   ['Plum purple with a small purple-tinted head ...
# 6298   ['Hard to get hype- DDH Fort Point kills this ...
# 3494   ['Sample at Mikkeller Beer Celebration Copenha...
# 1184   ['Having on draft in a pint glass. Dark amber ...
# 9844   ["Poured from a 16oz can into a tulip glass. H...
# 2910   ['Pours a fairly clear dark red color with a t...
# 7487   ['12oz can from the brewery. Pours a murky dir...
# 4058   ['Black pour at 55 degrees with no ruby edges;...
# 3285   ['5 ounce pour at 3 Floyds in Munster. Nice da...
# 6539   ['L: cloudy dark brown with full head of small...
# 83     ['Sample at Mikkeller Beer Celebration Copenha...
# 5245   ['Copper colored with a very clear complexion....
# 8520   ['Poured from can cloudy yellow. Amazing fruit...
# 3951   ['Pours black with a one inch frothy light bro...
# 9837   ['160z can purchased at the Canton brewery dat...
# 3322   ['Pours dark black with a small tan head. Smel...
# 5259   ['Bright copper orange in color with perfect c...
# 5112   ['16 oz can. Pours cloudy yellow orange with t...
# 4683   ['Bright hazy yellow beer with low white bubbl...
# 7694   ['Amazing. Completely opaque milky golden appe...
# 7549   ['Ink black pour with two fingers of dark tan ...
# 6857   ['Old school meets new school. Grapefruit and ...
# 7279   ['16-oz. can 10/30/18 needed a medium-strong p...
# 722    ['2016 Vintage. Pours dark brown, not super th...
# 4968   ['Red/amber/lite brown pour; quick thin white ...
# 4097   ['Overall this was very underwhelming. Jan 201...
# 7506   ['If Madagascar and Abraxas had a few too many...
# 10029  ['Lots of what makes Trillium beers so good: b...
#
#                                              BeerName  Rating  \
# 7144                                            Green    4.84
# 7386                               Oude Geuze Vintage    4.67
# 1936                                      Triple Shot    4.58
# 3320                    Barrel-Aged Sump Coffee Stout    4.39
# 12                        Kentucky Brunch Brand Stout    4.87
# 9070                                          Crusher    4.05
# 5558          Jackie O's / Side Project - Appervation    4.90
# 661                                        JJJuliusss    4.07
# 4902                              Clare's Thirsty Ale    4.59
# 9466                              Clare's Thirsty Ale    4.59
# 9201                                             DFPF    4.74
# 7958                                            Bomb!    4.47
# 1753                                     Chemtrailmix    4.38
# 9278                                            Bodhi    3.74
# 9200                                             DFPF    4.79
# 3502                           Montmorency Vs Balaton    4.67
# 4079        Genealogy Of Morals - Bourbon Barrel-Aged    4.88
# 8597               Speedway Stout - Vietnamese Coffee    4.50
# 7650                            Society & Solitude #5    4.32
# 3778               Speedway Stout - Vietnamese Coffee    4.77
# 8603               Speedway Stout - Vietnamese Coffee    4.50
# 10074          Expedition Stout - Bourbon Barrel-Aged    4.75
# 4824                   Ten FIDY - Bourbon Barrel Aged    4.19
# 2274                                       Black Gold    4.69
# 8327                          Kaggen! Stormaktsporter    4.97
# 3533               Melcher Street (Double Dry-Hopped)    4.49
# 3423                                        The Abyss    4.18
# 10013                                  Coconut B-Bomb    4.39
# 5735                                   Coconut B-Bomb    4.93
# 2442                               It Was All A Dream    4.99
# ...                                               ...     ...
# 3101                                         Framboos    4.14
# 1790                                  Triple Sunshine    4.46
# 2001                                   Saint Lamvinus    4.20
# 6298                                    Juice Machine    4.18
# 3494                           Montmorency Vs Balaton    3.90
# 1184                                            Citra    4.25
# 9844                                         Vicinity    3.87
# 2910                                     Consecration    4.22
# 7487                                  Triple Sunshine    4.24
# 4058                         Apple Brandy Barrel Noir    4.71
# 3285                                Permanent Funeral    4.34
# 6539                   Trappist Westvleteren 12 (XII)    4.16
# 83                                Barrel-Aged Abraxas    4.70
# 5245                            Hop JuJu Imperial IPA    4.29
# 8520                              Congress Street IPA    4.55
# 3951                                        Last Snow    4.42
# 9837                                         Vicinity    4.53
# 3322                    Barrel-Aged Sump Coffee Stout    4.60
# 5259                            Hop JuJu Imperial IPA    4.37
# 5112           Double Dry Hopped All Citra Everything    4.71
# 4683                                       Temptation    4.21
# 7694         Ghost In The Machine - Double Dry-Hopped    4.99
# 7549                                 Black Note Stout    4.79
# 6857                                    Double Citra®    4.40
# 7279                                             Haze    4.53
# 722                                          Parabola    4.38
# 4968                        Rodenbach Caractère Rouge    4.85
# 4097        Genealogy Of Morals - Bourbon Barrel-Aged    4.00
# 7506   Grande Negro Voodoo Papi - Bourbon Barrel-Aged    4.79
# 10029                Double Dry Hopped Sleeper Street    3.82
#
#        spacy_similarity              attributes overall_sentiment  \
# 7144           0.549736  malty crisp aggressive          Positive
# 7386           0.577835  malty crisp aggressive          Positive
# 1936           0.561672  malty crisp aggressive          Positive
# 3320           0.631427  malty crisp aggressive          Positive
# 12             0.553011  malty crisp aggressive          Positive
# 9070           0.557274  malty crisp aggressive          Positive
# 5558           0.552786  malty crisp aggressive          Positive
# 661            0.548436  malty crisp aggressive          Positive
# 4902           0.619732  malty crisp aggressive          Positive
# 9466           0.619732  malty crisp aggressive          Positive
# 9201           0.550027  malty crisp aggressive          Positive
# 7958           0.564232  malty crisp aggressive          Positive
# 1753           0.631216  malty crisp aggressive          Positive
# 9278           0.595301  malty crisp aggressive          Positive
# 9200           0.571711  malty crisp aggressive          Positive
# 3502           0.562049  malty crisp aggressive          Positive
# 4079           0.560217  malty crisp aggressive          Positive
# 8597           0.572317  malty crisp aggressive          Positive
# 7650           0.591061  malty crisp aggressive          Positive
# 3778           0.561723  malty crisp aggressive          Positive
# 8603           0.574126  malty crisp aggressive          Positive
# 10074          0.595140  malty crisp aggressive          Positive
# 4824           0.553606  malty crisp aggressive          Positive
# 2274           0.577443  malty crisp aggressive          Positive
# 8327           0.558503  malty crisp aggressive          Positive
# 3533           0.552490  malty crisp aggressive          Positive
# 3423           0.564834  malty crisp aggressive          Positive
# 10013          0.566992  malty crisp aggressive          Positive
# 5735           0.573907  malty crisp aggressive          Positive
# 2442           0.559540  malty crisp aggressive          Positive
# ...                 ...                     ...               ...
# 3101           0.565152  malty crisp aggressive          Positive
# 1790           0.559810  malty crisp aggressive          Positive
# 2001           0.592032  malty crisp aggressive          Positive
# 6298           0.560511  malty crisp aggressive          Positive
# 3494           0.556929  malty crisp aggressive          Positive
# 1184           0.565657  malty crisp aggressive          Positive
# 9844           0.556391  malty crisp aggressive          Positive
# 2910           0.584458  malty crisp aggressive          Positive
# 7487           0.551658  malty crisp aggressive          Positive
# 4058           0.596904  malty crisp aggressive          Positive
# 3285           0.605186  malty crisp aggressive          Positive
# 6539           0.606299  malty crisp aggressive          Positive
# 83             0.586916  malty crisp aggressive          Positive
# 5245           0.549652  malty crisp aggressive           Neutral
# 8520           0.550288  malty crisp aggressive           Neutral
# 3951           0.559771  malty crisp aggressive           Neutral
# 9837           0.556428  malty crisp aggressive           Neutral
# 3322           0.590935  malty crisp aggressive           Neutral
# 5259           0.666506  malty crisp aggressive          Negative
# 5112           0.604393  malty crisp aggressive          Negative
# 4683           0.564327  malty crisp aggressive          Negative
# 7694           0.552555  malty crisp aggressive          Negative
# 7549           0.587657  malty crisp aggressive          Negative
# 6857           0.586402  malty crisp aggressive          Negative
# 7279           0.578202  malty crisp aggressive          Negative
# 722            0.567324  malty crisp aggressive          Negative
# 4968           0.558462  malty crisp aggressive          Negative
# 4097           0.591339  malty crisp aggressive          Negative
# 7506           0.575408  malty crisp aggressive          Negative
# 10029          0.571822  malty crisp aggressive          Negative
#
#       sentiment_score
# 7144           0.9977
# 7386           0.9976
# 1936           0.9974
# 3320           0.9965
# 12             0.9945
# 9070           0.9893
# 5558           0.9892
# 661            0.9874
# 4902           0.9874
# 9466           0.9874
# 9201           0.9871
# 7958           0.9865
# 1753           0.9859
# 9278           0.9855
# 9200           0.9849
# 3502           0.9845
# 4079            0.983
# 8597           0.9828
# 7650           0.9816
# 3778           0.9813
# 8603            0.981
# 10074          0.9808
# 4824           0.9794
# 2274           0.9792
# 8327            0.979
# 3533            0.979
# 3423           0.9785
# 10013          0.9778
# 5735           0.9777
# 2442           0.9776
# ...               ...
# 3101           0.2952
# 1790           0.2732
# 2001           0.2263
# 6298           0.2023
# 3494           0.1573
# 1184            0.128
# 9844           0.1181
# 2910           0.1065
# 7487           0.1045
# 4058           0.0974
# 3285           0.0775
# 6539           0.0772
# 83             0.0644
# 5245            0.024
# 8520                0
# 3951                0
# 9837                0
# 3322           -0.024
# 5259          -0.0886
# 5112           -0.126
# 4683          -0.2854
# 7694          -0.2942
# 7549          -0.3641
# 6857          -0.3818
# 7279          -0.5267
# 722           -0.5327
# 4968          -0.5499
# 4097          -0.6098
# 7506          -0.7506
# 10029           -0.87
#
# [300 rows x 7 columns]

# %% [markdown]
# ### Task E
# Top 3 beer recommendations based on spacy similarity and sentiment score

# %%
#Converting the sentiment_score and spacy_similarity to float type
top300['sentiment_score'] = top300['sentiment_score'].astype(float)
top300['spacy_similarity'] = top300['spacy_similarity'].astype(float)

# %%
# Calculating average similarity and sentiment scores for each beer  
avg = top300.groupby(['BeerName'])['Rating','sentiment_score','spacy_similarity'].mean().sort_values(by = ['sentiment_score'],ascending=False)
avg
# Out:
#                                                 Rating  sentiment_score  \
# BeerName
# Green                                           4.8400         0.997700
# Oude Geuze Vintage                              4.6700         0.997600
# Clare's Thirsty Ale                             4.5900         0.987400
# DFPF                                            4.7650         0.986000
# Bodhi                                           3.7400         0.985500
# Ten FIDY - Bourbon Barrel Aged                  4.1900         0.979400
# Black Gold                                      4.6900         0.979200
# Coconut B-Bomb                                  4.6600         0.977750
# It Was All A Dream                              4.9900         0.977600
# Speedway Stout - Vietnamese Coffee              4.5525         0.976000
# Art                                             4.2500         0.974400
# Marshmallow Handjee                             4.7500         0.973800
# Pirate Paradise                                 4.7400         0.973400
# Bourbon Paradise                                4.6600         0.973200
# Abraxas                                         4.8900         0.972900
# Weihenstephaner Hefeweissbier                   4.1100         0.970800
# Cable Car                                       4.7400         0.970500
# Bourbon Barrel Oro Negro                        4.9000         0.969800
# Expedition Stout - Bourbon Barrel-Aged          4.4800         0.969150
# SR-71                                           4.8100         0.967300
# Kentucky Brunch Brand Stout                     4.9100         0.965500
# In Perpetuity                                   4.5300         0.961767
# Society & Solitude #6                           4.5800         0.961400
# Pliny The Younger                               4.9700         0.959100
# JJJuliusss                                      4.3450         0.958700
# Barrel Aged Bomb!                               4.3200         0.955900
# Flora                                           4.6300         0.954500
# CBS (Canadian Breakfast Stout)                  4.4600         0.953200
# Double Nelson                                   4.3600         0.947900
# Kaggen! Stormaktsporter                         4.6300         0.943367
# ...                                                ...              ...
# Double Dry Hopped All Citra Everything          4.5700         0.555867
# Citra                                           4.6050         0.551200
# Darkstar November                               4.2500         0.540000
# Mornin' Delight                                 4.5000         0.519900
# Enjoy By IPA                                    4.4800         0.493900
# Barrel-Aged Sump Coffee Stout                   4.4950         0.486250
# Beyond Good And Evil                            4.2100         0.475400
# Last Snow                                       4.3800         0.472000
# Vicinity                                        4.4225         0.458675
# Trappist Westvleteren 8 (VIII)                  4.7200         0.445500
# Heavy Mettle                                    4.2400         0.421500
# Zenne Y Frontera                                4.8100         0.381800
# Lou Pepe - Kriek                                4.6600         0.361200
# Consecration                                    4.3500         0.346200
# Temptation                                      4.4400         0.338450
# Ghost In The Machine - Double Dry-Hopped        4.7900         0.336750
# Sure Bet                                        4.1900         0.326200
# Framboos                                        4.1400         0.295200
# Congress Street IPA                             4.5550         0.285450
# Double Citra®                                   4.5750         0.264050
# Saint Lamvinus                                  4.2000         0.226300
# Triple Sunshine                                 4.3500         0.188850
# Haze                                            4.6850         0.128900
# Hop JuJu Imperial IPA                           4.3500         0.125267
# Trappist Westvleteren 12 (XII)                  4.1600         0.077200
# Double Dry Hopped Sleeper Street                4.2200        -0.111100
# Black Note Stout                                4.7900        -0.364100
# Parabola                                        4.3800        -0.532700
# Rodenbach Caractère Rouge                       4.8500        -0.549900
# Grande Negro Voodoo Papi - Bourbon Barrel-Aged  4.7900        -0.750600
#
#                                                 spacy_similarity
# BeerName
# Green                                                   0.549736
# Oude Geuze Vintage                                      0.577835
# Clare's Thirsty Ale                                     0.619732
# DFPF                                                    0.560869
# Bodhi                                                   0.595301
# Ten FIDY - Bourbon Barrel Aged                          0.553606
# Black Gold                                              0.577443
# Coconut B-Bomb                                          0.570449
# It Was All A Dream                                      0.559540
# Speedway Stout - Vietnamese Coffee                      0.575256
# Art                                                     0.568452
# Marshmallow Handjee                                     0.570329
# Pirate Paradise                                         0.558289
# Bourbon Paradise                                        0.557488
# Abraxas                                                 0.575579
# Weihenstephaner Hefeweissbier                           0.605103
# Cable Car                                               0.567556
# Bourbon Barrel Oro Negro                                0.553539
# Expedition Stout - Bourbon Barrel-Aged                  0.592284
# SR-71                                                   0.569203
# Kentucky Brunch Brand Stout                             0.557170
# In Perpetuity                                           0.567949
# Society & Solitude #6                                   0.549563
# Pliny The Younger                                       0.597413
# JJJuliusss                                              0.552943
# Barrel Aged Bomb!                                       0.552661
# Flora                                                   0.555235
# CBS (Canadian Breakfast Stout)                          0.549782
# Double Nelson                                           0.567548
# Kaggen! Stormaktsporter                                 0.579026
# ...                                                          ...
# Double Dry Hopped All Citra Everything                  0.570940
# Citra                                                   0.563843
# Darkstar November                                       0.581927
# Mornin' Delight                                         0.570130
# Enjoy By IPA                                            0.550978
# Barrel-Aged Sump Coffee Stout                           0.611181
# Beyond Good And Evil                                    0.560792
# Last Snow                                               0.567180
# Vicinity                                                0.564194
# Trappist Westvleteren 8 (VIII)                          0.595061
# Heavy Mettle                                            0.562842
# Zenne Y Frontera                                        0.584770
# Lou Pepe - Kriek                                        0.549530
# Consecration                                            0.582127
# Temptation                                              0.565636
# Ghost In The Machine - Double Dry-Hopped                0.554419
# Sure Bet                                                0.574018
# Framboos                                                0.565152
# Congress Street IPA                                     0.556368
# Double Citra®                                           0.572758
# Saint Lamvinus                                          0.592032
# Triple Sunshine                                         0.555734
# Haze                                                    0.565507
# Hop JuJu Imperial IPA                                   0.593008
# Trappist Westvleteren 12 (XII)                          0.606299
# Double Dry Hopped Sleeper Street                        0.585708
# Black Note Stout                                        0.587657
# Parabola                                                0.567324
# Rodenbach Caractère Rouge                               0.558462
# Grande Negro Voodoo Papi - Bourbon Barrel-Aged          0.575408
#
# [170 rows x 3 columns]

# %%
print("Recommended beers to the customer based on the given preferences: " + str(words))
avg.head(3)
# Out:
# Recommended beers to the customer based on the given preferences: malty crisp aggressive
#                      Rating  sentiment_score  spacy_similarity
# BeerName
# Green                  4.84           0.9977          0.549736
# Oude Geuze Vintage     4.67           0.9976          0.577835
# Clare's Thirsty Ale    4.59           0.9874          0.619732

# %% [markdown]
# ### Task F
# Beer recommendations if we ignored the similarity and sentiment scores.
# Only considering the average user ratings from dataset.

# %%
top3 = comments.groupby(['Beer Name'])['Rating'].mean().sort_values(ascending=False).head(3)

# %%
#Top 3 Beer based on rating
print("The top three highest rated beers from whole dataset:")
comments.groupby(['Beer Name'])['Rating'].mean().sort_values(ascending=False).head(3)
# Out:
# The top three highest rated beers from whole dataset:
# Beer Name
# Kentucky Brunch Brand Stout    4.815882
# Chemtrailmix                   4.811176
# It Was All A Dream             4.785000
# Name: Rating, dtype: float64

# %% [markdown]
# ### Supporting Analysis
# Differences in our recommendation vs. the top-rated beers

# %%
#Finding similarity scores for the reviews of the top 3 rated beers we found from Task F

# %%
threebeers = comments.groupby(['Beer Name'])['Rating'].mean().sort_values(ascending=False).head(3)

# %%
topthreecomments = top300[top300['BeerName'].isin(threebeers.index)].copy()
topthreecomments
# Out:
#                                             User Review  \
# 1753  ['11/17/18 (Chicago): 2 oz 15.0% ABV pour at 2...
# 1754  ['L: Dark mocha and chestnut hues with a rust-...
# 4     ['Poured black as ink with thin ruby edges at ...
# 2442  ['L: Rich and thick mahogany mocha hues with a...
# 6096  ['2016 batch', 'L: Pours an insanely thick dar...
# 12    ["Pouring with a thick viscosity that's damn n...
#
#                          BeerName  Rating  spacy_similarity  \
# 1753                 Chemtrailmix    4.38          0.631216
# 1754                 Chemtrailmix    4.74          0.577062
# 4     Kentucky Brunch Brand Stout    4.97          0.563839
# 2442           It Was All A Dream    4.99          0.559540
# 6096  Kentucky Brunch Brand Stout    4.89          0.554660
# 12    Kentucky Brunch Brand Stout    4.87          0.553011
#
#                   attributes overall_sentiment  sentiment_score
# 1753  malty crisp aggressive          Positive           0.9859
# 1754  malty crisp aggressive          Positive           0.4854
# 4     malty crisp aggressive          Positive           0.9622
# 2442  malty crisp aggressive          Positive           0.9776
# 6096  malty crisp aggressive          Positive           0.9398
# 12    malty crisp aggressive          Positive           0.9945

# %%
topthreecomments.groupby(["BeerName"])['Rating','sentiment_score','spacy_similarity'].mean()
# Out:
#                              Rating  sentiment_score  spacy_similarity
# BeerName
# Chemtrailmix                   4.56          0.73565          0.604139
# It Was All A Dream             4.99          0.97760          0.559540
# Kentucky Brunch Brand Stout    4.91          0.96550          0.557170

# %% [markdown]
# ### Analysis

# %% [markdown]
# Following are the recommendations we extracted from Task E and Task F respectively. Task E contains the beers that we recommended using the sentiment scores and similarities. Task F simply contains the top three highest rated beers.
# <br>The highest rated beers will not meet the requirements of the user because they all have lower sentiment scores than the ones from our recommendations. We speculate that this is because these beers do not take into consideration the user's preferred attributes.
# <br>Any user looking for recommendations has specific traits of beer that they prefer which may not align with the general public's taste and/or rating. It is likely that this user does not just want to be suggested the overall highest rated beers but instead wants more personalized recommendations which may not be mainstream.

# %% [markdown]
# <table align="left" style="border: 1px solid black">
#     <tr>
#         <th style="border: 1px solid black">Our Recommendations - Task E</th>
#         <th style="border: 1px solid black">Highest Rated - Task F</th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black"><img src='our-recs.png' height="300" width="400"></td>
#         <td style="border: 1px solid black"><img src='top-rated.png' height="300" width="400"></td>
#     </tr>
# </table>
